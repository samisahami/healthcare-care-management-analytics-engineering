# %% [markdown]
# # Healthcare CM Engagement Pipeline Planning
#
# ## Stakeholder Request
# Care management leadership wants a monthly reporting pipeline to:
# - track member engagement
# - monitor utilization/cost trends
# - identify members needing outreach prioritization
#
# ## Synthetic Source Tables
# 1. members
# 2. eligibility
# 3. claims
# 4. interactions
# 5. care_management_episodes
# 6. providers
# 7. facilities
#
# ## Planned Business Outputs
# - member monthly utilization mart
# - engagement status mart
# - outreach prioritization mart
# - executive KPI dashboard mart
